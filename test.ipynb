# %%
import pandas as pd
import requests

# %%
players = {
    "Kylian Mbappé":"278"
}

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/players"

querystring = {"id":"278","season":"2023"}

headers = {
	"x-rapidapi-key": "d0403ab417msh0da98e6741731b8p16bfe9jsne4c347e4038f",
	"x-rapidapi-host": "api-football-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'get': 'players', 'parameters': {'id': '278', 'season': '2023'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'player': {'id': 278, 'name': 'K. Mbappé', 'firstname': 'Kylian', 'lastname': 'Mbappé Lottin', 'age': 26, 'birth': {'date': '1998-12-20', 'place': 'Paris', 'country': 'France'}, 'nationality': 'France', 'height': '178 cm', 'weight': '75 kg', 'injured': False, 'photo': 'https://media.api-sports.io/football/players/278.png'}, 'statistics': [{'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media.api-sports.io/football/teams/85.png'}, 'league': {'id': 61, 'name': 'Ligue 1', 'country': 'France', 'logo': 'https://media.api-sports.io/football/leagues/61.png', 'flag': 'https://media.api-sports.io/flags/fr.svg', 'season': 2023}, 'games': {'appearences': 29, 'lineups': 24, 'minutes': 2159, 'number': None, 'position': 'Attacker', 'rating': '7.917241', 'captain': False}, 'substitutes': {'in': 5, 'out': 5, 'bench': 7}, 'shots': {'total': 91, 'on': 59}, 'goals': {'total': 27, 'conceded': 0, 'assists': 7, 'saves': None}, 'passes': {'total': 931, 'key': 40, 'accuracy': 27}, 'tackles': {'total': 4, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 224, 'won': 103}, 'dribbles': {'attempts': 123, 'success': 61, 'past': None}, 'fouls': {'drawn': 38, 'committed': 19}, 'cards': {'yellow': 4, 'yellowred': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 6, 'missed': 2, 'saved': None}}, {'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media.api-sports.io/football/teams/85.png'}, 'league': {'id': 66, 'name': 'Coupe de France', 'country': 'France', 'logo': 'https://media.api-sports.io/football/leagues/66.png', 'flag': 'https://media.api-sports.io/flags/fr.svg', 'season': 2023}, 'games': {'appearences': 6, 'lineups': 6, 'minutes': 540, 'number': None, 'position': 'Attacker', 'rating': '8.566666', 'captain': False}, 'substitutes': {'in': 0, 'out': 0, 'bench': 0}, 'shots': {'total': 31, 'on': 23}, 'goals': {'total': 8, 'conceded': 0, 'assists': 3, 'saves': None}, 'passes': {'total': 268, 'key': 11, 'accuracy': 38}, 'tackles': {'total': 1, 'blocks': None, 'interceptions': 2}, 'duels': {'total': 52, 'won': 30}, 'dribbles': {'attempts': 36, 'success': 21, 'past': None}, 'fouls': {'drawn': 5, 'committed': 4}, 'cards': {'yellow': 0, 'yellowred': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 1, 'missed': 1, 'saved': None}}, {'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media.api-sports.io/football/teams/85.png'}, 'league': {'id': 2, 'name': 'UEFA Champions League', 'country': 'World', 'logo': 'https://media.api-sports.io/football/leagues/2.png', 'flag': None, 'season': 2023}, 'games': {'appearences': 12, 'lineups': 12, 'minutes': 1080, 'number': None, 'position': 'Attacker', 'rating': '7.666666', 'captain': False}, 'substitutes': {'in': 0, 'out': 0, 'bench': 0}, 'shots': {'total': 42, 'on': 27}, 'goals': {'total': 8, 'conceded': 0, 'assists': None, 'saves': None}, 'passes': {'total': 365, 'key': 26, 'accuracy': 25}, 'tackles': {'total': 2, 'blocks': None, 'interceptions': 4}, 'duels': {'total': 117, 'won': 54}, 'dribbles': {'attempts': 66, 'success': 36, 'past': None}, 'fouls': {'drawn': 12, 'committed': 11}, 'cards': {'yellow': 1, 'yellowred': 0, 'red': 0}, 'penalty': {'won': None, 'commited': None, 'scored': 2, 'missed': 0, 'saved': None}}, {'team': {'id': 85, 'name': 'Paris Saint Germain', 'logo': 'https://media.api-sports.io/football/teams/85.png'}, 'league': {'id': 667, 'name': 'Friendlies Clubs', 'country': 'World', 'logo': 'https://media.api-sports.io/football/leagues/667.png', 'flag': None, 'season': 2023}, 'games': {'appearences': 1, 'lineups': 0, 'minutes': 24, 'number': None, 'position': 'Attacker', 'rating': None, 'captain': False}, 'substitutes': {'in': 1, 'out': 0, 'bench': 1}, 'shots': {'total': None, 'on': None}, 'goals': {'total': 1, 'conceded': None, 'assists': None, 'saves': None}, 'passes': {'to ...

# %%
# List to hold each row of data
data_rows = []

# Iterate through each competition in the statistics list
player_name = response['response'][0]['player']['name']
for stats in response.json()['response'][0]['statistics']:
    competition_data = {
        "Name": player_name,
        "Competition": stats['league']['name'],
        "Team": stats['team']['name'],
        "Appearances": stats['games']['appearences'],
        "Lineups": stats['games']['lineups'],
        "Minutes": stats['games']['minutes'],
        "Goals": stats['goals']['total'],
        "Assists": stats['goals']['assists'],
        "Shots Total": stats['shots']['total'],
        "Shots On": stats['shots']['on'],
        "Passes Total": stats['passes']['total'],
        "Key Passes": stats['passes']['key'],
        "Pass Accuracy": stats['passes']['accuracy'],
        "Duels Total": stats['duels']['total'],
        "Duels Won": stats['duels']['won'],
        "Dribbles Attempts": stats['dribbles']['attempts'],
        "Dribbles Success": stats['dribbles']['success'],
        "Fouls Drawn": stats['fouls']['drawn'],
        "Fouls Committed": stats['fouls']['committed'],
        "Yellow Cards": stats['cards']['yellow'],
        "Red Cards": stats['cards']['red'],
        "Penalties Scored": stats['penalty']['scored'],
        "Penalties Missed": stats['penalty']['missed']
    }
    # Append the data for this competition to the list
    data_rows.append(competition_data)

# Create a DataFrame from the list of data rows
df = pd.DataFrame(data_rows)

# %%
df
# Out:
#                          Competition                 Team  Appearances  \
# 0                            Ligue 1  Paris Saint Germain           29
# 1                    Coupe de France  Paris Saint Germain            6
# 2              UEFA Champions League  Paris Saint Germain           12
# 3                   Friendlies Clubs  Paris Saint Germain            1
# 4  Euro Championship - Qualification               France            8
# 5                         Friendlies               France            1
#
#    Lineups  Minutes  Goals  Assists  Shots Total  Shots On  Passes Total  ...  \
# 0       24     2159     27      7.0         91.0      59.0         931.0  ...
# 1        6      540      8      3.0         31.0      23.0         268.0  ...
# 2       12     1080      8      NaN         42.0      27.0         365.0  ...
# 3        0       24      1      NaN          NaN       NaN           NaN  ...
# 4        7      656      9      5.0         29.0      16.0         412.0  ...
# 5        1       87      1      NaN          NaN       NaN           NaN  ...
#
#    Duels Total  Duels Won  Dribbles Attempts  Dribbles Success  Fouls Drawn  \
# 0        224.0      103.0              123.0              61.0         38.0
# 1         52.0       30.0               36.0              21.0          5.0
# 2        117.0       54.0               66.0              36.0         12.0
# 3          NaN        NaN                NaN               NaN          NaN
# 4         69.0       33.0               36.0              21.0         10.0
# 5          NaN        NaN                NaN               NaN          NaN
#
#    Fouls Committed  Yellow Cards  Red Cards  Penalties Scored  \
# 0             19.0             4          0               6.0
# 1              4.0             0          0               1.0
# 2             11.0             1          0               2.0
# 3              NaN             0          0               NaN
# 4              4.0             1          0               3.0
# 5              NaN             0          0               NaN
#
#    Penalties Missed
# 0               2.0
# 1               1.0
# 2               0.0
# 3               NaN
# 4               0.0
# 5               NaN
#
# [6 rows x 22 columns]
